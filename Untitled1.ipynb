# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv('country_vaccinations.csv')
df
# Out:
#            country iso_code        date  total_vaccinations  \
# 0      Afghanistan      AFG  2021-02-22                 0.0
# 1      Afghanistan      AFG  2021-02-23                 NaN
# 2      Afghanistan      AFG  2021-02-24                 NaN
# 3      Afghanistan      AFG  2021-02-25                 NaN
# 4      Afghanistan      AFG  2021-02-26                 NaN
# ...            ...      ...         ...                 ...
# 20385     Zimbabwe      ZWE  2021-05-20            867396.0
# 20386     Zimbabwe      ZWE  2021-05-21            887928.0
# 20387     Zimbabwe      ZWE  2021-05-22            904073.0
# 20388     Zimbabwe      ZWE  2021-05-23            911033.0
# 20389     Zimbabwe      ZWE  2021-05-24            914921.0
#
#        people_vaccinated  people_fully_vaccinated  daily_vaccinations_raw  \
# 0                    0.0                      NaN                     NaN
# 1                    NaN                      NaN                     NaN
# ...

# %%
df.shape
# Out:
# (20390, 15)

# %%
df.isnull().sum().sum()
# Out:
# 71761

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20390 entries, 0 to 20389
# Data columns (total 15 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   country                              20390 non-null  object
#  1   iso_code                             20390 non-null  object
#  2   date                                 20390 non-null  object
#  3   total_vaccinations                   11618 non-null  float64
#  4   people_vaccinated                    10859 non-null  float64
#  5   people_fully_vaccinated              8386 non-null   float64
#  6   daily_vaccinations_raw               9671 non-null   float64
#  7   daily_vaccinations                   20176 non-null  float64
#  8   total_vaccinations_per_hundred       11618 non-null  float64
#  9   people_vaccinated_per_hundred        10859 non-null  float64
#  10  people_fully_vaccinated_per_hundred  8386 non-null   float64
# ...

# %%
missing_value=df.isnull().sum()/df.shape[0]*100
missing_value.head()
# Out:
# country                0.000000
# iso_code               0.000000
# date                   0.000000
# total_vaccinations    43.021089
# people_vaccinated     46.743502
# dtype: float64

# %%
find_missing_value=missing_value[missing_value>50].keys()
find_missing_value
# Out:
# Index(['people_fully_vaccinated', 'daily_vaccinations_raw',
#        'people_fully_vaccinated_per_hundred'],
#       dtype='object')

# %%
drop_clms=df.drop(columns=find_missing_value)
drop_clms.shape
# Out:
# (20390, 12)

# %%
df2=drop_clms.select_dtypes(include=['float64'])
df2
# Out:
#        total_vaccinations  people_vaccinated  daily_vaccinations  \
# 0                     0.0                0.0                 NaN
# 1                     NaN                NaN              1367.0
# 2                     NaN                NaN              1367.0
# 3                     NaN                NaN              1367.0
# 4                     NaN                NaN              1367.0
# ...                   ...                ...                 ...
# 20385            867396.0           615296.0             16482.0
# 20386            887928.0           624665.0             16098.0
# 20387            904073.0           630348.0             15823.0
# 20388            911033.0           632496.0             16298.0
# 20389            914921.0           633635.0             14380.0
#
#        total_vaccinations_per_hundred  people_vaccinated_per_hundred  \
# 0                                0.00                           0.00
# ...

# %%
plt.figure(figsize=(10,5))
sns.heatmap(df2.isnull())
# Out:
# <AxesSubplot:>

# %%
df3=df2.fillna(df2.mean())
# df4=df2.fillna(df2.median())
df3.head()
# df4.head()
# Out:
#    total_vaccinations  people_vaccinated  daily_vaccinations  \
# 0        0.000000e+00       0.000000e+00        84862.052439
# 1        6.643173e+06       3.851860e+06         1367.000000
# 2        6.643173e+06       3.851860e+06         1367.000000
# 3        6.643173e+06       3.851860e+06         1367.000000
# 4        6.643173e+06       3.851860e+06         1367.000000
#
#    total_vaccinations_per_hundred  people_vaccinated_per_hundred  \
# 0                        0.000000                       0.000000
# 1                       19.341765                      13.629598
# 2                       19.341765                      13.629598
# 3                       19.341765                      13.629598
# 4                       19.341765                      13.629598
#
#    daily_vaccinations_per_million
# 0                     3142.786132
# 1                       35.000000
# 2                       35.000000
# 3                       35.000000
# ...

# %%
df2.head()
# Out:
#    total_vaccinations  people_vaccinated  daily_vaccinations  \
# 0                 0.0                0.0                 NaN
# 1                 NaN                NaN              1367.0
# 2                 NaN                NaN              1367.0
# 3                 NaN                NaN              1367.0
# 4                 NaN                NaN              1367.0
#
#    total_vaccinations_per_hundred  people_vaccinated_per_hundred  \
# 0                             0.0                            0.0
# 1                             NaN                            NaN
# 2                             NaN                            NaN
# 3                             NaN                            NaN
# 4                             NaN                            NaN
#
#    daily_vaccinations_per_million
# 0                             NaN
# 1                            35.0
# 2                            35.0
# 3                            35.0
# ...

# %%
df5=drop_clms.select_dtypes(include=['object'])
df5.head()
# Out:
#        country iso_code        date  \
# 0  Afghanistan      AFG  2021-02-22
# 1  Afghanistan      AFG  2021-02-23
# 2  Afghanistan      AFG  2021-02-24
# 3  Afghanistan      AFG  2021-02-25
# 4  Afghanistan      AFG  2021-02-26
#
#                                             vaccines  \
# 0  Oxford/AstraZeneca, Pfizer/BioNTech, Sinopharm...
# 1  Oxford/AstraZeneca, Pfizer/BioNTech, Sinopharm...
# 2  Oxford/AstraZeneca, Pfizer/BioNTech, Sinopharm...
# 3  Oxford/AstraZeneca, Pfizer/BioNTech, Sinopharm...
# 4  Oxford/AstraZeneca, Pfizer/BioNTech, Sinopharm...
#
#                  source_name            source_website
# 0  World Health Organization  https://covid19.who.int/
# 1  World Health Organization  https://covid19.who.int/
# 2  World Health Organization  https://covid19.who.int/
# 3  World Health Organization  https://covid19.who.int/
# 4  World Health Organization  https://covid19.who.int/

# %%
df5['source_name'].unique()
# Out:
# array(['World Health Organization', 'Ministry of Health',
#        'Government of Andorra', 'Government of Aruba',
#        'Government of Australia via covidlive.com.au',
#        'Government of Azerbaijan', 'Government of the Bahamas',
#        'Directorate General of Health Services', 'Sciensano',
#        'Government of Bermuda', 'Public Health Institute',
#        'Ministry of Health and Wellness',
#        'Official data from provinces via covid19tracker.ca',
#        'Cayman Islands Government',
#        'Department of Statistics and Health Information',
#        'National Health Commission', 'Costa Rican Social Security Fund',
#        'Ministry of Health and Public Hygiene', 'Government of Curacao',
#        'Statens Serum Institute', 'Government of Dominica',
#        'Ministry of Public Health', 'Government of Ecuador via Ecuacovid',
#        'Government of the United Kingdom', 'National Health Board',
#        'Government of Eswatini', 'Government of the Faeroe Islands',
# ...

# %%
df5.isnull().mean()*100  #find categorical value is null percentage or is null
                         #apply mode method to categorical value df5[cat_val].mode()
                         #df5[cat_val].value_counts it counts how many categorical value you inplaced
# Out:
# country           0.0
# iso_code          0.0
# date              0.0
# vaccines          0.0
# source_name       0.0
# source_website    0.0
# dtype: float64

# %%
plt.figure(figsize=(8,3))
sns.heatmap(df5.isnull())
sns.heatmap(df3.isnull())
# Out:
# <AxesSubplot:>
